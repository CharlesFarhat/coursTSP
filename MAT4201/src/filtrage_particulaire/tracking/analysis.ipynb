# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N_eff_60 = np.loadtxt("./tab_lamda_60.txt")
N_eff_20 = np.loadtxt("./tab_lamda_20.txt")
N_eff_10 = np.loadtxt("./tab.txt")

# %%
plt.plot(N_eff_20, label="lambda = 20")
plt.plot(N_eff_60, label="lambda = 60")
#plt.plot(N_eff_10, label="lambda = 10")
plt.legend()
plt.title("N_eff en fonction du temps")
plt.xlabel("temps (ici les images)")
plt.ylabel("N_eff")
plt.show()
